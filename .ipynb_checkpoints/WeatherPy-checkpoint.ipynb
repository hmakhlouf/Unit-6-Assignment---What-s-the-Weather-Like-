# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %%
#print(cities)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# eg: http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1c1f0ef346b8b82d638f6bd65672e6dd&q=avarua 

# base url
base_url = "http://api.openweathermap.org/data/2.5/weather?"

#Params 
units = "Imperial"
APPID = api_key
q = cities

# %%
# # disply all the results 
# for city in cities:
#     q_url = base_url+"units="+units+"&APPID="+APPID+"&q="+city
#     weatherpy = requests.get(q_url).json()
#     #print(weatherpy)
#     print(json.dumps(weatherpy, indent=4, sort_keys=True))

# %%
# create dataframe for city data

weatherpy_df = pd.DataFrame(cities)
weatherpy_df.columns=["City"]
#weatherpy_df.head()


#set aditional columns 
weatherpy_df['Cloudiness'] = ""
weatherpy_df['Country'] = ""
weatherpy_df['Date'] = ""
weatherpy_df['Humidity'] = ""
weatherpy_df['Lat'] = ""
weatherpy_df['Lan'] = ""
weatherpy_df['Max_Temp'] = ""
weatherpy_df['Wind_Speed'] = ""


weatherpy_df.head()
# Out:
#            City Cloudiness Country Date Humidity Lat Lan Max_Temp Wind_Speed
# 0  puerto ayora
# 1        rawson
# 2       mataura
# 3     fairbanks
# 4       rikitea

# %%
# setup 
record = 0
set = 1



print("Beginning Data Retrieval")
print("------------------------------")


for index, row in city_df.iterrows():
# for row in city_df.iterrows():
    city = row['City']
    
    try:
        q_url = base_url+"units="+units+"&APPID="+APPID+"&q="+city
        weatherpy = requests.get(q_url).json()
        
        print(f"processing record {record} of set {set} | {city}")
        
#         city_df.loc[index, 'City'] = response['name']
        weatherpy_df.loc[index, 'Lan'] = weatherpy['coord']['lon']
        weatherpy_df.loc[index, 'Lat'] = weatherpy['coord']['lat']
        weatherpy_df.loc[index, 'Cloudiness'] = weatherpy['clouds']['all']
        weatherpy_df.loc[index, 'Country'] = weatherpy['sys']['country']
        weatherpy_df.loc[index, 'Date'] =  weatherpy['dt']
        weatherpy_df.loc[index, 'Humidity'] = weatherpy['main']['humidity']
        weatherpy_df.loc[index, 'Max_Temp'] = weatherpy['main']['temp_max']
        weatherpy_df.loc[index, 'Wind_Speed']= weatherpy['wind']['speed']
        
        
        record = record + 1
        if record >= 51:
            record= 0
            set = set + 1
        
    except (KeyError, IndexError):
        print("City not found. Skipping...")

        
        
# Data Retrieval Complete      

print("---------------------------")
print("Data Retrieval Complete ")
print("---------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# processing record 0 of set 1 | madison heights
# processing record 1 of set 1 | cherskiy
# processing record 2 of set 1 | slave lake
# processing record 3 of set 1 | thompson
# processing record 4 of set 1 | port lincoln
# processing record 5 of set 1 | demba
# processing record 6 of set 1 | mataura
# processing record 7 of set 1 | vaini
# processing record 8 of set 1 | talaya
# processing record 9 of set 1 | lengshuitan
# processing record 10 of set 1 | yellowknife
# processing record 11 of set 1 | hermanus
# processing record 12 of set 1 | riyadh
# processing record 13 of set 1 | tasiilaq
# processing record 14 of set 1 | kununurra
# processing record 15 of set 1 | qaanaaq
# processing record 16 of set 1 | samusu
# City not found. Skipping...
# processing record 16 of set 1 | fortuna
# processing record 17 of set 1 | punta arenas
# processing record 13 of set 5 | lakes entrance
# processing record 14 of set 5 | terney
# processing record 15 of set 5 | obo
# processing record 16 of set 5 | virginia beach
# processing record 17 of set 5 | mongoumba
# processing record 18 of set 5 | kodinsk
# processing record 19 of set 5 | matagami
# processing record 20 of set 5 | caravelas
# processing record 21 of set 5 | grand river south east
# City not found. Skipping...
# processing record 21 of set 5 | lodja
# processing record 22 of set 5 | richards bay
# processing record 23 of set 5 | el alto
# processing record 24 of set 5 | jumla
# processing record 25 of set 5 | flin flon
# processing record 26 of set 5 | chokurdakh
# processing record 27 of set 5 | manzanillo
# processing record 28 of set 5 | adrar
# processing record 29 of set 5 | jacareacanga
# processing record 30 of set 5 | salina
# processing record 31 of set 5 | naze
# processing record 32 of set 5 | pathein
# processing record 33 of set 5 | sterling
# processing record 34 of set 5 | bonthe
# processing record 35 of set 5 | isla mujeres
# processing record 36 of set 5 | viedma
# processing record 37 of set 5 | yebaishou
# processing record 38 of set 5 | palmer
# processing record 39 of set 5 | anjozorobe
# processing record 40 of set 5 | coquimbo
# processing record 41 of set 5 | codrington
# processing record 42 of set 5 | solnechnyy
# processing record 43 of set 5 | kaspiyskiy
# processing record 44 of set 5 | odweyne
# City not found. Skipping...
# processing record 44 of set 5 | portland
# processing record 45 of set 5 | quatre cocos
# processing record 46 of set 5 | goderich
# processing record 47 of set 5 | aflu
# City not found. Skipping...
# processing record 47 of set 5 | umarkot
# processing record 48 of set 5 | akyab
# City not found. Skipping...
# processing record 48 of set 5 | san jeronimo
# processing record 49 of set 5 | pemba
# processing record 50 of set 5 | medicine hat
# processing record 0 of set 6 | marienburg
# processing record 1 of set 6 | ostrovnoy
# processing record 2 of set 6 | cap malheureux
# processing record 3 of set 6 | les cayes
# processing record 4 of set 6 | kulunda
# processing record 5 of set 6 | aksarka
# processing record 6 of set 6 | carnarvon
# processing record 7 of set 6 | nouadhibou
# processing record 8 of set 6 | dong hoi
# processing record 9 of set 6 | dargaville
# processing record 10 of set 6 | yatou
# processing record 11 of set 6 | ponta do sol
# processing record 12 of set 6 | mar del plata
# processing record 13 of set 6 | babanusah
# City not found. Skipping...
# processing record 13 of set 6 | clyde river
# processing record 14 of set 6 | guerrero negro
# processing record 15 of set 6 | amderma
# City not found. Skipping...
# processing record 15 of set 6 | srednekolymsk
# processing record 16 of set 6 | wau
# City not found. Skipping...
# processing record 16 of set 6 | ibipeba
# processing record 17 of set 6 | ust-nera
# processing record 18 of set 6 | tromso
# processing record 19 of set 6 | champerico
# processing record 20 of set 6 | maldonado
# processing record 21 of set 6 | samarai
# processing record 22 of set 6 | kodiak
# processing record 23 of set 6 | kargasok
# processing record 24 of set 6 | yirol
# City not found. Skipping...
# processing record 24 of set 6 | mahuva
# processing record 25 of set 6 | sitka
# processing record 26 of set 6 | vaitape
# processing record 27 of set 6 | deputatskiy
# processing record 28 of set 6 | carahue
# processing record 29 of set 6 | alekseyevskoye
# processing record 30 of set 6 | itoman
# processing record 31 of set 6 | zhigansk
# processing record 32 of set 6 | luganville
# processing record 33 of set 6 | pacifica
# processing record 34 of set 6 | khatanga
# processing record 35 of set 6 | bengkulu
# City not found. Skipping...
# processing record 35 of set 6 | selma
# processing record 36 of set 6 | bandarbeyla
# processing record 37 of set 6 | buchanan
# processing record 38 of set 6 | potosi
# processing record 39 of set 6 | katsuura
# processing record 40 of set 6 | camacha
# processing record 41 of set 6 | faya
# processing record 42 of set 6 | aden
# processing record 43 of set 6 | ponta delgada
# processing record 44 of set 6 | barbar
# City not found. Skipping...
# processing record 44 of set 6 | duns
# processing record 45 of set 6 | miri
# processing record 46 of set 6 | talara
# processing record 47 of set 6 | taft
# processing record 48 of set 6 | guekedou
# City not found. Skipping...
# processing record 48 of set 6 | mayo
# processing record 49 of set 6 | bubaque
# processing record 50 of set 6 | kalmunai
# processing record 0 of set 7 | zheleznodorozhnyy
# processing record 1 of set 7 | kavieng
# processing record 2 of set 7 | peniche
# processing record 3 of set 7 | kamenskoye
# City not found. Skipping...
# processing record 3 of set 7 | touros
# processing record 4 of set 7 | abnub
# processing record 5 of set 7 | zonguldak
# processing record 6 of set 7 | labytnangi
# processing record 7 of set 7 | bull savanna
# processing record 8 of set 7 | araouane
# processing record 9 of set 7 | trelew
# processing record 10 of set 7 | alpena
# processing record 11 of set 7 | zemio
# processing record 12 of set 7 | montepuez
# processing record 13 of set 7 | saldanha
# processing record 14 of set 7 | atasu
# processing record 15 of set 7 | asau
# City not found. Skipping...
# processing record 15 of set 7 | ixtapa
# processing record 16 of set 7 | saint-augustin
# processing record 17 of set 7 | port blair
# processing record 18 of set 7 | ban nahin
# processing record 19 of set 7 | grindavik
# processing record 20 of set 7 | khani
# processing record 21 of set 7 | sao joao da barra
# processing record 22 of set 7 | mulege
# processing record 23 of set 7 | bay city
# processing record 24 of set 7 | lardos
# processing record 25 of set 7 | igarka
# processing record 26 of set 7 | maniitsoq
# processing record 27 of set 7 | boa vista
# processing record 28 of set 7 | shingu
# processing record 29 of set 7 | tokur
# processing record 30 of set 7 | caibarien
# processing record 31 of set 7 | victoria
# processing record 32 of set 7 | marcona
# City not found. Skipping...
# processing record 32 of set 7 | arraial do cabo
# processing record 33 of set 7 | havoysund
# processing record 34 of set 7 | kuala terengganu
# processing record 35 of set 7 | takoradi
# processing record 36 of set 7 | pousat
# City not found. Skipping...
# processing record 36 of set 7 | vaitupu
# City not found. Skipping...
# processing record 36 of set 7 | hilo
# processing record 37 of set 7 | quang ngai
# processing record 38 of set 7 | sinnamary
# processing record 39 of set 7 | erenhot
# processing record 40 of set 7 | alta floresta
# processing record 41 of set 7 | saint george
# processing record 42 of set 7 | develi
# processing record 43 of set 7 | te anau
# processing record 44 of set 7 | yanan
# City not found. Skipping...
# processing record 44 of set 7 | maple creek
# processing record 45 of set 7 | amlagora
# processing record 46 of set 7 | westport
# processing record 47 of set 7 | sinjar
# processing record 48 of set 7 | ende
# processing record 19 of set 9 | naryan-mar
# processing record 20 of set 9 | palana
# processing record 21 of set 9 | temaraia
# City not found. Skipping...
# processing record 21 of set 9 | grand centre
# City not found. Skipping...
# processing record 21 of set 9 | maneadero
# City not found. Skipping...
# processing record 21 of set 9 | inirida
# processing record 22 of set 9 | spencer
# processing record 23 of set 9 | san jose
# processing record 24 of set 9 | rawson
# processing record 25 of set 9 | san cristobal
# processing record 26 of set 9 | plettenberg bay
# processing record 27 of set 9 | dzaoudzi
# processing record 28 of set 9 | santiago
# processing record 29 of set 9 | alekseyevsk
# processing record 30 of set 9 | la rioja
# processing record 31 of set 9 | lufilufi
# processing record 32 of set 9 | verkhnyaya inta
# processing record 33 of set 9 | mtwango
# processing record 34 of set 9 | sisimiut
# processing record 35 of set 9 | tezu
# processing record 36 of set 9 | kerki
# City not found. Skipping...
# processing record 36 of set 9 | mount isa
# processing record 37 of set 9 | artyk
# City not found. Skipping...
# processing record 37 of set 9 | padang
# processing record 38 of set 9 | turukhansk
# processing record 39 of set 9 | waitara
# processing record 40 of set 9 | haikou
# processing record 41 of set 9 | oriximina
# processing record 42 of set 9 | betma
# processing record 43 of set 9 | galesong
# processing record 44 of set 9 | sibolga
# processing record 45 of set 9 | dongning
# processing record 46 of set 9 | ahipara
# processing record 47 of set 9 | tucuma
# City not found. Skipping...
# processing record 47 of set 9 | mersing
# processing record 48 of set 9 | bone
# processing record 49 of set 9 | puerto narino
# processing record 50 of set 9 | arawa
# processing record 0 of set 10 | te kauwhata
# processing record 1 of set 10 | quartucciu
# processing record 2 of set 10 | antalaha
# processing record 3 of set 10 | lumberton
# processing record 4 of set 10 | marawi
# processing record 5 of set 10 | ambon
# processing record 6 of set 10 | mopipi
# processing record 7 of set 10 | killybegs
# processing record 8 of set 10 | vestmannaeyjar
# processing record 9 of set 10 | bud
# processing record 10 of set 10 | walvis bay
# processing record 11 of set 10 | batagay-alyta
# processing record 12 of set 10 | macaboboni
# City not found. Skipping...
# processing record 12 of set 10 | henties bay
# processing record 13 of set 10 | kattivakkam
# processing record 14 of set 10 | aripuana
# processing record 15 of set 10 | zvishavane
# processing record 16 of set 10 | zaranj
# processing record 17 of set 10 | matara
# processing record 18 of set 10 | general roca
# processing record 19 of set 10 | winnemucca
# processing record 20 of set 10 | karwar
# processing record 21 of set 10 | oudtshoorn
# processing record 22 of set 10 | poum
# processing record 23 of set 10 | ukiah
# processing record 24 of set 10 | sapa
# processing record 25 of set 10 | aasiaat
# processing record 26 of set 10 | lavrentiya
# processing record 27 of set 10 | ahuimanu
# processing record 28 of set 10 | marzuq
# processing record 29 of set 10 | phalodi
# processing record 30 of set 10 | umm kaddadah
# processing record 31 of set 10 | evansville
# processing record 32 of set 10 | kotlyarevskaya
# processing record 33 of set 10 | were ilu
# processing record 34 of set 10 | tsihombe
# City not found. Skipping...
# processing record 34 of set 10 | yichun
# processing record 35 of set 10 | airai
# processing record 36 of set 10 | kroya
# processing record 37 of set 10 | morinville
# processing record 38 of set 10 | sabla
# processing record 39 of set 10 | toucheng
# processing record 40 of set 10 | assiros
# processing record 41 of set 10 | anadyr
# processing record 42 of set 10 | tombouctou
# processing record 43 of set 10 | alihe
# processing record 44 of set 10 | chapleau
# processing record 45 of set 10 | namatanai
# processing record 46 of set 10 | ushibuka
# processing record 47 of set 10 | hare bay
# processing record 48 of set 10 | haftoni
# processing record 49 of set 10 | sladkovo
# processing record 50 of set 10 | terrace
# processing record 0 of set 11 | constantine
# processing record 1 of set 11 | medea
# processing record 2 of set 11 | benguela
# processing record 3 of set 11 | warrnambool
# processing record 4 of set 11 | ous
# processing record 5 of set 11 | yorosso
# processing record 6 of set 11 | lolua
# City not found. Skipping...
# processing record 6 of set 11 | jiangmen
# City not found. Skipping...
# processing record 6 of set 11 | naantali
# processing record 7 of set 11 | presidencia roque saenz pena
# processing record 8 of set 11 | kandrian
# processing record 9 of set 11 | khambhaliya
# processing record 10 of set 11 | karsun
# processing record 11 of set 11 | belmonte
# processing record 12 of set 11 | acajutla
# processing record 13 of set 11 | burnie
# processing record 14 of set 11 | gushikawa
# processing record 15 of set 11 | cayenne
# processing record 16 of set 11 | grand gaube
# processing record 17 of set 11 | khorramabad
# processing record 18 of set 11 | abu samrah
# processing record 19 of set 11 | agbor
# processing record 20 of set 11 | bilma
# processing record 21 of set 11 | chabahar
# processing record 22 of set 11 | pudozh
# processing record 23 of set 11 | orizona
# processing record 24 of set 11 | nemuro
# processing record 25 of set 11 | mackay
# processing record 26 of set 11 | sao filipe
# processing record 27 of set 11 | gorontalo
# processing record 28 of set 11 | tabora
# processing record 29 of set 11 | trofors
# processing record 30 of set 11 | khalkhal
# processing record 31 of set 11 | yaounde
# processing record 32 of set 11 | coxim
# processing record 33 of set 11 | sola
# processing record 34 of set 11 | flinders
# processing record 35 of set 11 | gogrial
# City not found. Skipping...
# processing record 35 of set 11 | pucallpa
# processing record 36 of set 11 | waipawa
# processing record 37 of set 11 | troina
# processing record 38 of set 11 | umm lajj
# processing record 39 of set 11 | boda
# processing record 40 of set 11 | inta
# processing record 41 of set 11 | kazalinsk
# City not found. Skipping...
# processing record 41 of set 11 | okhotsk
# processing record 42 of set 11 | sao miguel do araguaia
# ---------------------------
# Data Retrieval Complete
# ---------------------------

# %% [markdown]
# # disply the DataFrame

# %%
weatherpy_df.head()
# Out:
#            City Cloudiness Country        Date Humidity    Lat     Lan  \
# 0  puerto ayora         75      US  1558328185       93  42.49  -83.11
# 1        rawson        100      RU  1558328185       94  68.75   161.3
# 2       mataura          1      CA  1558328186       35  55.28 -114.77
# 3     fairbanks         20      CA  1558328186       62  55.74  -97.86
# 4       rikitea         28      AU  1558328187       79 -34.72  135.86
#
#   Max_Temp Wind_Speed
# 0       63       3.36
# 1     27.3       10.4
# 2     55.4      10.29
# 3     44.6       9.17
# 4    63.12      16.51

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weatherpy_df.count()
# Out:
# City          636
# Cloudiness    636
# Country       636
# Date          636
# Humidity      636
# Lat           636
# Lan           636
# Max_Temp      636
# Wind_Speed    636
# dtype: int64

# %%
# Save city data to a csv file
weatherpy_df.to_csv("output_data/cities.csv", index=False)

# %%
weatherpy_df.head()
# Out:
#            City Cloudiness Country        Date Humidity    Lat     Lan  \
# 0  puerto ayora         75      US  1558328185       93  42.49  -83.11
# 1        rawson        100      RU  1558328185       94  68.75   161.3
# 2       mataura          1      CA  1558328186       35  55.28 -114.77
# 3     fairbanks         20      CA  1558328186       62  55.74  -97.86
# 4       rikitea         28      AU  1558328187       79 -34.72  135.86
#
#   Max_Temp Wind_Speed
# 0       63       3.36
# 1     27.3       10.4
# 2     55.4      10.29
# 3     44.6       9.17
# 4    63.12      16.51

# %%
weatherpy_df.dtypes
# Out:
# City          object
# Cloudiness    object
# Country       object
# Date          object
# Humidity      object
# Lat           object
# Lan           object
# Max_Temp      object
# Wind_Speed    object
# dtype: object

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
weather_df = pd.read_csv("output_data/cities.csv")
weather_df.head()
# Out:
#            City  Cloudiness Country          Date  Humidity    Lat     Lan  \
# 0  puerto ayora        75.0      US  1.558328e+09      93.0  42.49  -83.11
# 1        rawson       100.0      RU  1.558328e+09      94.0  68.75  161.30
# 2       mataura         1.0      CA  1.558328e+09      35.0  55.28 -114.77
# 3     fairbanks        20.0      CA  1.558328e+09      62.0  55.74  -97.86
# 4       rikitea        28.0      AU  1.558328e+09      79.0 -34.72  135.86
#
#    Max_Temp  Wind_Speed
# 0     63.00        3.36
# 1     27.30       10.40
# 2     55.40       10.29
# 3     44.60        9.17
# 4     63.12       16.51

# %%
weather_df.dtypes
# Out:
# City           object
# Cloudiness    float64
# Country        object
# Date          float64
# Humidity      float64
# Lat           float64
# Lan           float64
# Max_Temp      float64
# Wind_Speed    float64
# dtype: object

# %%
# x & y coordinates 
x1 = weather_df["Lat"]
y1 = weather_df["Max_Temp"]

#disply scatter plot
plt.scatter(x1, y1, marker="o", facecolors="dodgerblue", edgecolor="black", alpha=0.80)

#label/title/ grid 

plt.title("City Latitude vs. Max Temperature (8/22/18)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# save the plot 
plt.savefig("images/latitude_temp.png")


# Display the graph
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x2 = weather_df["Lat"]
y2 = weather_df["Humidity"]

plt.scatter(x2, y2, marker="o", facecolors="dodgerblue", edgecolor="black", alpha=0.80)

plt.title("City Latitude vs. Humidity (08/22/18)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("images/latitude_humidity.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x3 = weather_df["Lat"]
y3 = weather_df["Cloudiness"]



plt.scatter(x3, y3, marker="o", facecolors="dodgerblue", edgecolor="black", alpha=0.80)



plt.title("City Latitude vs. Cloudiness (08/22/18)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)



plt.savefig("images/latitude_cloudiness.png")



plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x4 = weather_df["Lat"]
y4 = weather_df["Wind_Speed"]


plt.scatter(x4, y4, marker="o", facecolors="dodgerblue", edgecolor="black", alpha=0.80)


plt.title("City Latitude vs. Wind Speed (08/22/18)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)


plt.savefig("images/latitude_wind_speed.png")


plt.show()
